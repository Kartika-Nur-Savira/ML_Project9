# %%
print("mari mengerjakan project ini")
# Out:
# mari mengerjakan project ini

# %%
# !pip install matplotlib seaborn scipy --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 1.9 MB/s  0:00:03m0:00:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.3/30.3 MB 839.5 kB/s  0:00:34m0:00:0100:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 1.5 MB/s  0:00:01 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 1.2 MB/s  0:00:03 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [seaborn]9/10 [seaborn]ib]esources]
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
from scipy import stats
import warnings
 
warnings.filterwarnings("ignore")
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
FILE_PATH = "breast_cancer_40_features_1M.csv"

df_full = pd.read_csv(FILE_PATH, nrows=500_000)
df_full.head(5)
# Out:
#    radius_mean  texture_mean  perimeter_mean    area_mean  smoothness_mean  \
# 0    16.021426     15.900191       80.338711   806.403104        -0.234153
# 1    14.074327     14.990334       72.827789   622.307690        -1.478522
# 2    14.893529     17.008014       89.946616   696.859332        -0.808494
# 3     9.392390     16.336167       54.760612   277.141849         0.586857
# 4    18.038859     18.218585      129.752145  1022.275649         0.963376
#
#    compactness_mean  concavity_mean  concave_points_mean  symmetry_mean  \
# 0         -0.234137        1.579213             0.767435      -0.469474
# 1         -0.719844       -0.460639             1.057122       0.343618
# 2         -0.501757        0.915402             0.328751      -0.529760
# 3          2.190456       -0.990536            -0.566298       0.099651
# 4          0.412781        0.822060             1.896793      -0.245388
#
#    fractal_dimension_mean  ...  nucleus_size  nucleus_texture  mitosis_rate  \
# ...
